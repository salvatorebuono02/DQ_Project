# %% [markdown]
# # Upload Dataset

# %%
from SCRIPTS.A_data_collection import make_dataset_for_regression
#The number of informative features, i.e., the number of features used to build the linear model used to generate the output.
X, y = make_dataset_for_regression(n_samples=1000, n_features=10, n_informative=5, n_targets=1, bias=0.0, effective_rank=None, tail_strength=0.5, noise=0.0, seed=2023)
print(X.shape)
print(y.shape)
# Out:
# (1000, 10)
# (1000,)

# %% [markdown]
# # Data analysis
# Try to understand duplicates, range of values, functional dependencies

# %%
import pandas as pd

df = pd.DataFrame(X)
print(df.head())
# Out:
#           0         1         2         3         4         5         6  \
# 0 -1.687523  1.162717 -0.533602 -0.628703 -0.829337  0.042886  0.344324
# 1 -1.020632 -0.220116 -0.869748  1.966181  0.835520 -0.296532  0.869868
# 2  0.523867 -1.125007  0.085100  0.323081  0.598603  2.014563  0.827047
# 3 -0.762037  0.471784 -0.558538 -0.813294  0.039496 -0.577744  0.756322
# 4 -0.082485 -1.466384 -0.212735 -1.422577 -1.848497 -0.464045  1.178404
#
#           7         8         9
# 0  0.724020 -1.314765 -0.475478
# 1  0.196561  0.281992 -0.401782
# 2  0.397878 -0.820872 -0.063909
# 3  0.423918  0.886604 -2.272658
# 4 -1.065657 -1.367547 -2.501120

# %%
df.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# 5    float64
# 6    float64
# 7    float64
# 8    float64
# 9    float64
# dtype: object

# %% [markdown]
# ### Single column analysis

# %%
distinct_values=df[0].nunique()
print(distinct_values)
# Out:
# 1000

# %%
mean_values = df.mean()
std_values = df.std()

print("Mean values:")
print(mean_values)

print("Standard deviation values:")
print(std_values)
# Out:
# Mean values:
# 0    0.005780
# 1   -0.031556
# 2   -0.016019
# 3    0.036449
# 4   -0.023135
# 5   -0.001820
# 6   -0.026303
# 7    0.007726
# 8    0.018629
# 9    0.092134
# dtype: float64
# Standard deviation values:
# 0    0.991113
# 1    0.975035
# 2    0.982018
# 3    1.023308
# 4    0.966829
# 5    1.022371
# 6    0.987888
# 7    0.972030
# 8    1.026852
# 9    1.001554
# dtype: float64

# %% [markdown]
# # Data pollution

# %% [markdown]
# ## Generate a complete random pollution function

# %%
# List of names
names = ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Henry', 'Ivy', 'Jack','John', 'Kate', 'Larry', 'Michael', 'Nancy', 'Oliver', 'Pete', 'Robert', 'Susan', 'Tom']

# List of surnames
surnames = ['Smith', 'Johnson', 'Williams', 'Jones', 'Brown', 'Davis', 'Miller', 'Wilson', 'Moore', 'Taylor']

# %%
import pandas as pd
import numpy as np
import random

def random_pollution(dataset, percentage):
    polluted_dataset = dataset.copy()
    num_features_affected = int(len(dataset.columns) * percentage)
    random_indices = np.random.choice(len(dataset.columns), num_features_affected, replace=False)

    for idx in random_indices:
        column_name = dataset.columns[idx]
        #if data_type == 'numeric':
        if np.issubdtype(dataset[column_name].dtype, np.number):
            # Convert numeric feature to categorical or boolean
            prob= np.random.rand()
            if prob < 0.2:
                polluted_dataset[column_name] = np.random.choice(['red', 'green', 'blue','purple','orange','yellow','grey','white','black','pink'], size=len(dataset))
            elif prob < 0.4:
                polluted_dataset[column_name] = np.random.choice([True, False], size=len(dataset))
            elif prob < 0.6:
                polluted_dataset[column_name] = np.random.choice(names, size=len(dataset))
            elif prob < 0.8:
                polluted_dataset[column_name] = np.random.choice(100, size=len(dataset))
            else:
                polluted_dataset[column_name] = np.random.choice(surnames, size=len(dataset))

    return polluted_dataset

polluted_dataset = random_pollution(df, 0.5)
print(polluted_dataset.head())
# Out:
#         0         1   2      3         4      5         6      7         8  \
# 0    blue  1.162717  35   True -0.829337  False  0.344324   blue -1.314765
# 1  yellow -0.220116   5   True  0.835520   True  0.869868   grey  0.281992
# 2     red -1.125007  87   True  0.598603   True  0.827047    red -0.820872
# 3  purple  0.471784  79  False  0.039496  False  0.756322  black  0.886604
# 4    pink -1.466384  60  False -1.848497   True  1.178404   pink -1.367547
#
#           9
# 0 -0.475478
# 1 -0.401782
# 2 -0.063909
# 3 -2.272658
# 4 -2.501120

# %% [markdown]
# ## Generate a pollution function according dataset values

# %%
def map_value_to_color(value):
    if value >= 0 and value < 0.1:
        return 'blue'
    elif value >= 0.1 and value < 0.2:
        return 'red'
    # Add more conditions for other ranges and corresponding colors
    elif value >= 0.2 and value < 0.3:
        return 'green'
    elif value >= 0.3 and value < 0.4:
        return 'purple'
    elif value >= 0.4 and value < 0.5:
        return 'yellow'
    elif value >= 0.5 and value < 0.6:
        return 'orange'
    elif value >= 0.6 and value < 0.7:
        return 'pink'
    elif value >= 0.7 and value < 0.8:
        return 'grey'
    elif value >= 0.8 and value < 0.9:
        return 'white'
    else:
        return 'black'

# %%
def map_value_to_name(value):
    if value >= 0 and value < 0.2:
        return 'Alice'
    elif value >= 0.2 and value < 0.4:
        return 'Charlie'
    elif value >= 0.4 and value < 0.6:
        return 'David'
    elif value >= 0.6 and value < 0.8:
        return 'Eve'
    else:
        return 'Frank'

# %%
def map_to_boolean(value):
    if value >= 0 and value < 0.5:
        return True
    else:
        return False

# %%
def map_to_surname(value):
    if value >= 0 and value < 0.2:
        return 'Smith'
    elif value >= 0.2 and value < 0.4:
        return 'Johnson'
    elif value >= 0.4 and value < 0.6:
        return 'Williams'
    elif value >= 0.6 and value < 0.8:
        return 'Jones'
    else:
        return 'Brown'

# %%
num=0.145
print(int(round(num, 2)*100))
# Out:
# 14

# %%
def map_to_integer(value):
    return int(round(value, 2)*100)

# %% [markdown]
# Scaling values before injecting pollution is crucial as it aids in the construction of the pollution function because I want to ensure that the function behaves consistently across different ranges of values. If data isn't scaled, the same amount of "pollution" could have a big impact on smaller values and a small impact on larger values. This could lead to inconsistent results and make it harder to understand the effects of the pollution.

# %%
from sklearn.preprocessing import MinMaxScaler
def range_based_pollution(dataset, percentage):
    num_features_affected = int(len(dataset.columns) * percentage)
    random_indices = np.random.choice(len(dataset.columns), num_features_affected, replace=False)
    random_indices = np.sort(random_indices)
    # Copy the dataset to avoid modifying the original dataset
    polluted_dataset = dataset.copy()

    # Scale only the columns in random_indices
    scaler=MinMaxScaler()
    columns_to_scale = polluted_dataset.columns[random_indices]
    polluted_dataset[columns_to_scale] = scaler.fit_transform(polluted_dataset[columns_to_scale])

    name_counter = 1
    surname_counter = 1
    names_columns = []
    surnames_columns = []

    for idx in random_indices:
        # Generate an integer random number between 0 and 3
        random_number = random.randint(0, 4)
        column = polluted_dataset.columns[idx]
        if random_number == 0:
            polluted_dataset[column] = polluted_dataset[column].apply(map_value_to_color)
        elif random_number == 1:
            new_column_name = 'names' + str(name_counter)
            polluted_dataset[column] = polluted_dataset[column].apply(map_value_to_name)
            polluted_dataset.rename(columns={column: new_column_name}, inplace=True)
            names_columns.append(new_column_name)
            name_counter += 1
        elif random_number == 2:
            polluted_dataset[column] = polluted_dataset[column].apply(map_to_boolean)
        elif random_number == 3:
            polluted_dataset[column] = polluted_dataset[column].apply(map_to_integer)
        else:
            new_column_name = 'surnames' + str(surname_counter)
            polluted_dataset[column] = polluted_dataset[column].apply(map_to_surname)
            polluted_dataset.rename(columns={column: new_column_name}, inplace=True)
            surnames_columns.append(new_column_name)
            surname_counter += 1
        
    print(polluted_dataset.dtypes)

    if names_columns and surnames_columns:
        # Concatenate all 'names' columns together
        polluted_dataset['names'] = polluted_dataset[names_columns].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)
        
        # Concatenate all 'surnames' columns together
        polluted_dataset['surnames'] = polluted_dataset[surnames_columns].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)
        
        # Create 'full_name' column by concatenating 'names' and 'surnames' columns
        polluted_dataset['full_name'] = polluted_dataset['names'] + ' ' + polluted_dataset['surnames']
        
    return polluted_dataset

polluted_dataset = range_based_pollution(df, 0.3)
print(polluted_dataset.head())
# Out:
# 0            float64
# 1            float64
# 2            float64
# 3            float64
# 4            float64
# 5              int64
# 6            float64
# surnames1     object
# 8            float64
# 9              int64
# dtype: object
#           0         1         2         3         4   5         6 surnames1  \
# 0 -1.687523  1.162717 -0.533602 -0.628703 -0.829337  47  0.344324  Williams
# 1 -1.020632 -0.220116 -0.869748  1.966181  0.835520  42  0.869868  Williams
# 2  0.523867 -1.125007  0.085100  0.323081  0.598603  77  0.827047  Williams
# 3 -0.762037  0.471784 -0.558538 -0.813294  0.039496  37  0.756322  Williams
# 4 -0.082485 -1.466384 -0.212735 -1.422577 -1.848497  39  1.178404   Johnson
#
#           8   9
# 0 -1.314765  49
# 1  0.281992  50
# 2 -0.820872  54
# 3  0.886604  24
# 4 -1.367547  21

# %% [markdown]
# ## Statistics of the polluted dataset

# %%
for idx in range(len(polluted_dataset.columns)):
    print(polluted_dataset.iloc[:, idx].value_counts())
    distinct_values = (polluted_dataset.iloc[:, idx].nunique())
    print(distinct_values)
    if distinct_values < 15:
        print(polluted_dataset.iloc[:, idx].value_counts())
    else:
        print("Too many distinct values to print")
    uniqueness = distinct_values / len(polluted_dataset)
    print("Uniqueness: ", uniqueness)
    print ('min:', polluted_dataset.iloc[:, idx].min())
    print ('max:', polluted_dataset.iloc[:, idx].max())
    print ('mode:', polluted_dataset.iloc[:, idx].mode()[0])
# Out:
# 0
# -1.687523    1
# -0.771916    1
#  0.056629    1
#  2.256737    1
# -0.455979    1
#             ..
# -1.649683    1
# -0.797178    1
# -0.325989    1
#  0.037820    1
# -1.127951    1
# Name: count, Length: 1000, dtype: int64
# 1000
# Too many distinct values to print
# Uniqueness:  1.0
# min: -3.2082926855229754
# max: 3.279456552430336
# mode: -3.2082926855229754
# 1
#  1.162717    1
# -1.122683    1
# -0.031318    1
#  0.361788    1
# -1.313228    1
#             ..
# -0.569984    1
#  0.071970    1
#  0.308531    1
#  0.766043    1
#  0.042814    1
# Name: count, Length: 1000, dtype: int64
# 1000
# Too many distinct values to print
# Uniqueness:  1.0
# min: -3.702650734489273
# max: 3.4570878539816565
# mode: -3.702650734489273
# 2
# -0.533602    1
# -0.339426    1
# -1.270515    1
#  0.350229    1
# -0.079330    1
#             ..
#  0.247250    1
#  1.868609    1
# -0.529002    1
# -0.483982    1
#  0.775350    1
# Name: count, Length: 1000, dtype: int64
# 1000
# Too many distinct values to print
# Uniqueness:  1.0
# min: -2.7560789184319727
# max: 3.412176776324521
# mode: -2.7560789184319727
# 3
# -0.628703    1
# -0.132170    1
# -1.702866    1
#  0.799889    1
# -0.115062    1
#             ..
# -0.836954    1
# -0.758316    1
#  1.422128    1
# -0.291956    1
#  0.454633    1
# Name: count, Length: 1000, dtype: int64
# 1000
# Too many distinct values to print
# Uniqueness:  1.0
# min: -3.283116018399808
# max: 3.173863318803175
# mode: -3.283116018399808
# 4
# -0.829337    1
#  0.485151    1
#  1.510059    1
#  0.146729    1
# -0.504873    1
#             ..
#  0.175960    1
#  1.723980    1
# -0.275888    1
#  0.744997    1
#  0.279408    1
# Name: count, Length: 1000, dtype: int64
# 1000
# Too many distinct values to print
# Uniqueness:  1.0
# min: -3.197886140964875
# max: 2.6293045135463387
# mode: -3.197886140964875
# 5
# 56    44
# 45    33
# 47    30
# 43    30
# 54    30
#       ..
# 83     1
# 86     1
# 8      1
# 1      1
# 7      1
# Name: count, Length: 82, dtype: int64
# 82
# Too many distinct values to print
# Uniqueness:  0.082
# min: 0
# max: 100
# mode: 56
# 6
#  0.344324    1
# -1.040190    1
#  0.748504    1
#  0.862092    1
# -1.246897    1
#             ..
# -0.009006    1
# -1.411160    1
#  0.799744    1
#  1.752756    1
# -0.568916    1
# Name: count, Length: 1000, dtype: int64
# 1000
# Too many distinct values to print
# Uniqueness:  1.0
# min: -2.8707440309580243
# max: 2.85692776356247
# mode: -2.8707440309580243
# surnames1
# Williams    481
# Johnson     282
# Jones       184
# Smith        36
# Brown        17
# Name: count, dtype: int64
# 5
# surnames1
# Williams    481
# Johnson     282
# Jones       184
# Smith        36
# Brown        17
# Name: count, dtype: int64
# Uniqueness:  0.005
# min: Brown
# max: Williams
# mode: Williams
# 8
# -1.314765    1
# -0.345546    1
#  1.236674    1
#  1.036137    1
#  0.947681    1
#             ..
# -0.437293    1
#  0.598048    1
#  0.170506    1
#  0.613495    1
#  0.716665    1
# Name: count, Length: 1000, dtype: int64
# 1000
# Too many distinct values to print
# Uniqueness:  1.0
# min: -3.459963185943204
# max: 3.3108622028075905
# mode: -3.459963185943204
# 9
# 56     69
# 54     39
# 63     33
# 57     32
# 51     32
#        ..
# 100     1
# 0       1
# 92      1
# 90      1
# 87      1
# Name: count, Length: 76, dtype: int64
# 76
# Too many distinct values to print
# Uniqueness:  0.076
# min: 0
# max: 100
# mode: 56

# %%
#import libraries and set up
import seaborn as sns

sns.set(color_codes=True)
sns.set_palette(sns.color_palette("muted"))

# %% [markdown]
# ### Statistics of injected value

# %%
import matplotlib.pyplot as plt

# Loop over each column
for column_name in polluted_dataset.columns:
    # Check if the column is non-numeric
    if not np.issubdtype(polluted_dataset[column_name].dtype, np.number):
        # Get the counts of each unique value in the column
        value_counts = polluted_dataset[column_name].value_counts()
        print(value_counts)
        # Create a bar plot of the counts
        plt.bar(value_counts.index, value_counts.values)

        # Show the plot
        plt.show()
# Out:
# surnames1
# Williams    481
# Johnson     282
# Jones       184
# Smith        36
# Brown        17
# Name: count, dtype: int64

# %% [markdown]
# These values reflect the value distribution shown below

# %% [markdown]
# ### Statistics of numerical value

# %%
# Loop over each column
for column_name in polluted_dataset.columns:
    # Check if the column is non-numeric
    if np.issubdtype(polluted_dataset[column_name].dtype, np.number):
        value_counts = polluted_dataset[column_name].value_counts()
        print(value_counts)
        # Create a histogram of the column values
        sns.displot(polluted_dataset[column_name])
# Out:
# 0
# -1.687523    1
# -0.771916    1
#  0.056629    1
#  2.256737    1
# -0.455979    1
#             ..
# -1.649683    1
# -0.797178    1
# -0.325989    1
#  0.037820    1
# -1.127951    1
# Name: count, Length: 1000, dtype: int64
# 1
#  1.162717    1
# -1.122683    1
# -0.031318    1
#  0.361788    1
# -1.313228    1
#             ..
# -0.569984    1
#  0.071970    1
#  0.308531    1
#  0.766043    1
#  0.042814    1
# Name: count, Length: 1000, dtype: int64
# 2
# -0.533602    1
# -0.339426    1
# -1.270515    1
#  0.350229    1
# -0.079330    1
#             ..
#  0.247250    1
#  1.868609    1
# -0.529002    1
# -0.483982    1
#  0.775350    1
# Name: count, Length: 1000, dtype: int64
# 3
# -0.628703    1
# -0.132170    1
# -1.702866    1
#  0.799889    1
# -0.115062    1
#             ..
# -0.836954    1
# -0.758316    1
#  1.422128    1
# -0.291956    1
#  0.454633    1
# Name: count, Length: 1000, dtype: int64
# 4
# -0.829337    1
#  0.485151    1
#  1.510059    1
#  0.146729    1
# -0.504873    1
#             ..
#  0.175960    1
#  1.723980    1
# -0.275888    1
#  0.744997    1
#  0.279408    1
# Name: count, Length: 1000, dtype: int64
# 5
# 56    44
# 45    33
# 47    30
# 43    30
# 54    30
#       ..
# 83     1
# 86     1
# 8      1
# 1      1
# 7      1
# Name: count, Length: 82, dtype: int64
# 6
#  0.344324    1
# -1.040190    1
#  0.748504    1
#  0.862092    1
# -1.246897    1
#             ..
# -0.009006    1
# -1.411160    1
#  0.799744    1
#  1.752756    1
# -0.568916    1
# Name: count, Length: 1000, dtype: int64
# 8
# -1.314765    1
# -0.345546    1
#  1.236674    1
#  1.036137    1
#  0.947681    1
#             ..
# -0.437293    1
#  0.598048    1
#  0.170506    1
#  0.613495    1
#  0.716665    1
# Name: count, Length: 1000, dtype: int64
# 9
# 56     69
# 54     39
# 63     33
# 57     32
# 51     32
#        ..
# 100     1
# 0       1
# 92      1
# 90      1
# 87      1
# Name: count, Length: 76, dtype: int64

# %% [markdown]
# # Regression

# %%
from SCRIPTS.D_data_analysis import regression, encoding_categorical_variables
from SCRIPTS.E_plot_results import plot

# REGRESSION EXAMPLE
    # (in this toy example, I simply created 10 datasets with respectively 1000,1001,1002,1003,1004,1005,1006,1007,1008,1009 number of samples
    # and I generated the three plots for the evaluation of the results)
results_for_each_algorithm = []
REGRESSION_ALGORITHMS = ["LinearRegressor","BayesianRidge","GPRegressor","SVMRegressor","KNNRegressor","MLPRegressor"]
SEED = 2023
for algorithm in REGRESSION_ALGORITHMS:  # FIRST CICLE ON THE ALGORITHMS

    results_single_algorithm = []

    for i in range(0,10):  # SECOND CICLE ON THE NUMBER OF POLLUTED DATASET THAT YOU WANT TO CREATE WITH DIFFERENT % OF POLLUTION
        # DATA COLLECTION
        X, y = make_dataset_for_regression(n_samples=1000+i*100, n_features=12, n_informative=4, n_targets=1, bias=0.0, effective_rank=None, tail_strength=0.5, noise=20.0, seed=2023)
        # DATA POLLUTION
        df = pd.DataFrame(X)
        # df = random_pollution(df, 0.3)
        df = range_based_pollution(df, 0.6)
        df.columns = df.columns.astype(str)
        df = encoding_categorical_variables(df)
        # DATA ANALYSIS
        results_1_analysis = regression(df, y, algorithm, SEED)
        results_single_algorithm.append(results_1_analysis)

    results_for_each_algorithm.append(results_single_algorithm)

# RESULTS EVALUATION
# EXAMPLE FOR USING THE SCRIPTS TO PLOT THE RESULTS
x_axis_values = [1000 + i * 100 for i in range(10)]
print(x_axis_values)

plot(x_axis_values, x_label="Number of samples", results=results_for_each_algorithm,title="Performance", algorithms=REGRESSION_ALGORITHMS, plot_type="performance")
plot(x_axis_values, x_label="Number of samples", results=results_for_each_algorithm,title="Distance train-test", algorithms=REGRESSION_ALGORITHMS, plot_type="distance train-test")
plot(x_axis_values, x_label="Number of samples", results=results_for_each_algorithm,title="Speed", algorithms=REGRESSION_ALGORITHMS, plot_type="speed")
# Out:
# 0            float64
# 1            float64
# 2            float64
# 3             object
# 4             object
# 5             object
# 6              int64
# 7               bool
# 8            float64
# surnames1     object
# 10           float64
# 11              bool
# dtype: object
# Training for LinearRegressor...
# surnames1     object
# names1        object
# 2            float64
# 3            float64
# 4            float64
# 5            float64
# surnames2     object
# 7             object
# 8               bool
# 9              int64
# names2        object
# 11           float64
# dtype: object
# Training for LinearRegressor...
# 0      object
# 1     float64
# 2     float64
# 3     float64
# 4       int64
# 5       int64
# 6       int64
# 7      object
# 8        bool
# 9     float64
# 10     object
# 11    float64
# dtype: object
# Training for LinearRegressor...
# 0            float64
# 1            float64
# 2               bool
# surnames1     object
# 4            float64
# names1        object
# 6            float64
# names2        object
# 8            float64
# 9               bool
# surnames2     object
# 11            object
# dtype: object
# Training for LinearRegressor...
# names1        object
# 1               bool
# 2            float64
# 3            float64
# 4             object
# 5            float64
# surnames1     object
# 7            float64
# names2        object
# 9              int64
# 10           float64
# names3        object
# dtype: object
# Training for LinearRegressor...
# 0             object
# 1            float64
# 2             object
# 3              int64
# 4            float64
# names1        object
# 6              int64
# 7            float64
# 8              int64
# 9            float64
# 10           float64
# surnames1     object
# dtype: object
# Training for LinearRegressor...
# 0            float64
# 1              int64
# 2             object
# 3             object
# 4              int64
# 5               bool
# surnames1     object
# 7            float64
# 8             object
# 9            float64
# 10           float64
# 11           float64
# dtype: object
# Training for LinearRegressor...
# 0     float64
# 1     float64
# 2     float64
# 3        bool
# 4      object
# 5     float64
# 6     float64
# 7        bool
# 8      object
# 9      object
# 10       bool
# 11     object
# dtype: object
# Training for LinearRegressor...
# 0               bool
# 1               bool
# names1        object
# surnames1     object
# 4            float64
# 5            float64
# 6              int64
# 7            float64
# 8            float64
# surnames2     object
# 10           float64
# 11              bool
# dtype: object
# Training for LinearRegressor...
# 0          object
# 1            bool
# 2         float64
# names1     object
# 4         float64
# 5         float64
# 6           int64
# 7            bool
# 8         float64
# 9         float64
# 10          int64
# names2     object
# dtype: object
# Training for LinearRegressor...
# names1        object
# 1            float64
# 2               bool
# 3            float64
# 4            float64
# names2        object
# 6             object
# surnames1     object
# 8            float64
# 9             object
# 10           float64
# surnames2     object
# dtype: object
# Training for BayesianRidge...
# 0            float64
# names1        object
# 2            float64
# 3               bool
# surnames1     object
# 5             object
# 6              int64
# 7            float64
# 8              int64
# surnames2     object
# 10           float64
# 11           float64
# dtype: object
# Training for BayesianRidge...
# 0             object
# 1            float64
# 2            float64
# 3            float64
# 4            float64
# names1        object
# surnames1     object
# 7             object
# 8            float64
# 9               bool
# 10             int64
# 11             int64
# dtype: object
# Training for BayesianRidge...
# 0               bool
# 1            float64
# 2               bool
# 3            float64
# 4              int64
# 5            float64
# 6              int64
# surnames1     object
# surnames2     object
# 9              int64
# 10           float64
# 11           float64
# dtype: object
# Training for BayesianRidge...
# 0               bool
# 1            float64
# 2            float64
# names1        object
# 4             object
# surnames1     object
# 6            float64
# 7               bool
# 8            float64
# surnames2     object
# 10           float64
# surnames3     object
# dtype: object
# Training for BayesianRidge...
# 0            float64
# 1            float64
# 2              int64
# 3             object
# names1        object
# names2        object
# 6               bool
# 7            float64
# surnames1     object
# 9            float64
# 10           float64
# surnames2     object
# dtype: object
# Training for BayesianRidge...
# 0            float64
# 1            float64
# 2             object
# 3              int64
# 4             object
# names1        object
# 6            float64
# 7              int64
# 8            float64
# 9            float64
# 10             int64
# surnames1     object
# dtype: object
# Training for BayesianRidge...
# 0               bool
# 1              int64
# 2            float64
# 3               bool
# 4            float64
# surnames1     object
# names1        object
# 7               bool
# 8            float64
# 9              int64
# 10           float64
# 11           float64
# dtype: object
# Training for BayesianRidge...
# 0              int64
# 1            float64
# 2            float64
# 3            float64
# names1        object
# surnames1     object
# names2        object
# 7             object
# surnames2     object
# 9            float64
# 10             int64
# 11           float64
# dtype: object
# Training for BayesianRidge...
# 0         float64
# 1            bool
# names1     object
# 3           int64
# 4         float64
# 5          object
# 6         float64
# 7         float64
# 8         float64
# 9           int64
# 10          int64
# 11          int64
# dtype: object
# Training for BayesianRidge...
# 0            float64
# 1            float64
# 2            float64
# 3              int64
# 4             object
# 5             object
# surnames1     object
# 7             object
# 8              int64
# 9               bool
# 10           float64
# 11           float64
# dtype: object
# Training for GPRegressor...
# 0             object
# names1        object
# 2             object
# 3            float64
# surnames1     object
# 5            float64
# 6            float64
# surnames2     object
# 8              int64
# surnames3     object
# 10           float64
# 11           float64
# dtype: object
# Training for GPRegressor...
# names1        object
# 1            float64
# 2            float64
# surnames1     object
# 4            float64
# surnames2     object
# surnames3     object
# 7            float64
# 8               bool
# 9            float64
# 10              bool
# 11            object
# dtype: object
# Training for GPRegressor...
# 0           int64
# 1           int64
# 2         float64
# names1     object
# 4         float64
# 5         float64
# 6         float64
# 7            bool
# 8           int64
# 9           int64
# 10          int64
# 11        float64
# dtype: object
# Training for GPRegressor...
# 0              int64
# 1              int64
# 2            float64
# 3               bool
# surnames1     object
# surnames2     object
# 6            float64
# 7            float64
# 8             object
# 9            float64
# 10              bool
# 11           float64
# dtype: object
# Training for GPRegressor...
# 0            float64
# 1             object
# 2            float64
# 3               bool
# 4            float64
# 5              int64
# 6               bool
# surnames1     object
# 8               bool
# 9            float64
# 10           float64
# 11              bool
# dtype: object
# Training for GPRegressor...
# names1        object
# 1               bool
# 2            float64
# names2        object
# 4            float64
# 5            float64
# 6             object
# surnames1     object
# names3        object
# 9            float64
# 10              bool
# 11           float64
# dtype: object
# Training for GPRegressor...
# 0           int64
# 1         float64
# 2          object
# 3           int64
# 4         float64
# 5            bool
# names1     object
# 7         float64
# 8            bool
# 9         float64
# 10           bool
# 11        float64
# dtype: object
# Training for GPRegressor...
# 0            float64
# names1        object
# 2             object
# 3              int64
# 4            float64
# names2        object
# 6              int64
# surnames1     object
# 8            float64
# 9               bool
# 10           float64
# 11           float64
# dtype: object
# Training for GPRegressor...
# 0            float64
# 1             object
# 2            float64
# names1        object
# 4            float64
# 5             object
# names2        object
# 7             object
# names3        object
# 9            float64
# surnames1     object
# 11           float64
# dtype: object
# Training for GPRegressor...
# 0               bool
# 1            float64
# 2            float64
# 3             object
# 4             object
# 5            float64
# 6            float64
# 7               bool
# surnames1     object
# 9            float64
# names1        object
# 11             int64
# dtype: object
# Training for SVMRegressor...
# names1        object
# 1            float64
# 2              int64
# surnames1     object
# 4            float64
# surnames2     object
# 6            float64
# 7            float64
# 8              int64
# 9             object
# 10            object
# 11           float64
# dtype: object
# Training for SVMRegressor...
# 0     float64
# 1        bool
# 2      object
# 3     float64
# 4        bool
# 5       int64
# 6       int64
# 7        bool
# 8     float64
# 9     float64
# 10      int64
# 11    float64
# dtype: object
# Training for SVMRegressor...
# 0            float64
# 1            float64
# names1        object
# 3            float64
# 4              int64
# 5            float64
# names2        object
# 7             object
# names3        object
# 9            float64
# 10              bool
# surnames1     object
# dtype: object
# Training for SVMRegressor...
# 0               bool
# 1              int64
# 2            float64
# 3            float64
# names1        object
# 5            float64
# 6            float64
# surnames1     object
# 8               bool
# 9             object
# 10             int64
# 11           float64
# dtype: object
# Training for SVMRegressor...
# names1     object
# 1            bool
# 2           int64
# 3          object
# 4         float64
# 5         float64
# 6         float64
# 7           int64
# 8          object
# 9          object
# 10        float64
# 11        float64
# dtype: object
# Training for SVMRegressor...
# surnames1     object
# 1            float64
# surnames2     object
# surnames3     object
# 4              int64
# 5            float64
# 6              int64
# 7            float64
# 8              int64
# 9            float64
# 10           float64
# 11            object
# dtype: object
# Training for SVMRegressor...
# 0              int64
# 1             object
# surnames1     object
# 3            float64
# 4            float64
# 5             object
# surnames2     object
# 7            float64
# names1        object
# 9            float64
# surnames3     object
# 11           float64
# dtype: object
# Training for SVMRegressor...
# 0          object
# 1         float64
# 2         float64
# 3          object
# 4           int64
# 5           int64
# 6         float64
# 7           int64
# 8         float64
# 9          object
# names1     object
# 11        float64
# dtype: object
# Training for SVMRegressor...
# 0               bool
# 1               bool
# 2              int64
# 3            float64
# 4            float64
# 5            float64
# 6            float64
# 7            float64
# names1        object
# 9               bool
# names2        object
# surnames1     object
# dtype: object
# Training for SVMRegressor...
# 0              int64
# names1        object
# 2              int64
# 3            float64
# 4            float64
# 5            float64
# 6             object
# 7            float64
# surnames1     object
# 9               bool
# 10           float64
# 11             int64
# dtype: object
# Training for KNNRegressor...
# 0            float64
# names1        object
# 2             object
# 3               bool
# 4              int64
# 5            float64
# 6            float64
# surnames1     object
# 8              int64
# 9            float64
# 10           float64
# 11             int64
# dtype: object
# Training for KNNRegressor...
# names1     object
# 1            bool
# 2         float64
# 3         float64
# 4         float64
# 5            bool
# 6           int64
# names2     object
# names3     object
# 9         float64
# 10        float64
# 11          int64
# dtype: object
# Training for KNNRegressor...
# 0             object
# 1             object
# 2            float64
# 3            float64
# surnames1     object
# 5            float64
# 6             object
# 7               bool
# 8               bool
# 9            float64
# 10           float64
# names1        object
# dtype: object
# Training for KNNRegressor...
# 0           int64
# 1           int64
# 2          object
# names1     object
# 4          object
# 5         float64
# 6          object
# 7         float64
# names2     object
# 9         float64
# 10        float64
# 11        float64
# dtype: object
# Training for KNNRegressor...
# 0              int64
# 1               bool
# surnames1     object
# 3             object
# 4              int64
# 5            float64
# 6            float64
# 7              int64
# 8              int64
# 9            float64
# 10           float64
# 11           float64
# dtype: object
# Training for KNNRegressor...
# 0            float64
# 1               bool
# 2            float64
# surnames1     object
# names1        object
# surnames2     object
# 6             object
# 7            float64
# 8            float64
# 9            float64
# surnames3     object
# 11              bool
# dtype: object
# Training for KNNRegressor...
# surnames1     object
# 1            float64
# names1        object
# 3            float64
# 4               bool
# names2        object
# surnames2     object
# 7               bool
# 8            float64
# 9             object
# 10           float64
# 11           float64
# dtype: object
# Training for KNNRegressor...
# 0            float64
# 1            float64
# 2            float64
# names1        object
# 4            float64
# 5              int64
# 6            float64
# 7              int64
# surnames1     object
# names2        object
# 10              bool
# names3        object
# dtype: object
# Training for KNNRegressor...
# surnames1     object
# 1             object
# names1        object
# 3            float64
# 4            float64
# surnames2     object
# 6            float64
# names2        object
# 8            float64
# 9             object
# names3        object
# 11           float64
# dtype: object
# Training for KNNRegressor...
# 0               bool
# 1            float64
# 2            float64
# surnames1     object
# 4             object
# names1        object
# surnames2     object
# surnames3     object
# 8               bool
# 9            float64
# 10           float64
# 11           float64
# dtype: object
# Training for MLPRegressor...
# 0               bool
# 1            float64
# 2             object
# 3            float64
# surnames1     object
# 5            float64
# 6             object
# 7              int64
# 8            float64
# names1        object
# 10              bool
# 11           float64
# dtype: object
# Training for MLPRegressor...
# 0            float64
# 1               bool
# 2            float64
# names1        object
# surnames1     object
# names2        object
# 6            float64
# surnames2     object
# names3        object
# 9            float64
# 10              bool
# 11           float64
# dtype: object
# Training for MLPRegressor...
# 0            float64
# 1            float64
# names1        object
# surnames1     object
# 4              int64
# 5            float64
# surnames2     object
# 7             object
# 8             object
# 9            float64
# surnames3     object
# 11           float64
# dtype: object
# Training for MLPRegressor...
# surnames1     object
# 1              int64
# names1        object
# names2        object
# 4            float64
# 5              int64
# 6            float64
# 7            float64
# 8             object
# 9              int64
# 10           float64
# 11           float64
# dtype: object
# Training for MLPRegressor...
# names1     object
# 1         float64
# names2     object
# 3         float64
# 4           int64
# 5          object
# 6         float64
# 7         float64
# 8         float64
# 9          object
# names3     object
# 11           bool
# dtype: object
# Training for MLPRegressor...
# 0            float64
# 1              int64
# 2             object
# 3            float64
# 4              int64
# 5            float64
# 6            float64
# surnames1     object
# surnames2     object
# 9            float64
# names1        object
# 11            object
# dtype: object
# Training for MLPRegressor...
# 0            float64
# 1            float64
# 2            float64
# 3             object
# names1        object
# surnames1     object
# names2        object
# surnames2     object
# 8              int64
# 9             object
# 10           float64
# 11           float64
# dtype: object
# Training for MLPRegressor...
# surnames1     object
# 1            float64
# 2              int64
# 3            float64
# 4            float64
# 5             object
# 6            float64
# 7            float64
# 8              int64
# 9               bool
# names1        object
# 11             int64
# dtype: object
# Training for MLPRegressor...
# 0               bool
# 1              int64
# surnames1     object
# 3            float64
# 4            float64
# 5            float64
# 6             object
# 7              int64
# 8            float64
# 9               bool
# names1        object
# 11           float64
# dtype: object
# Training for MLPRegressor...
# [1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900]

# %%
import pandas as pd

# Flatten the list of dictionaries and add algorithm name
flattened_results = []
for algorithm, results in zip(REGRESSION_ALGORITHMS, results_for_each_algorithm):
    for result in results:
        result['algorithm'] = algorithm
        flattened_results.append(result)

# Convert flattened results into a DataFrame
results_df = pd.DataFrame(flattened_results)
results_df
# Out:
#      mean_perf    distance      speed        algorithm
# 0    21.413470    0.969480   0.048009  LinearRegressor
# 1    74.510431   16.904770   0.225585  LinearRegressor
# 2    29.871048    1.606744   0.054332  LinearRegressor
# 3    49.919888   12.942259   0.174529  LinearRegressor
# 4    26.889068    5.115694   0.089606  LinearRegressor
# 5    40.816945    2.413688   0.053045  LinearRegressor
# 6    31.950998    1.143225   0.071887  LinearRegressor
# 7    24.331890    0.956271   0.019977  LinearRegressor
# 8    35.482804    1.609996   0.127703  LinearRegressor
# 9    27.612340    1.112850   0.017956  LinearRegressor
# 10   22.740818    5.466287   0.722878    BayesianRidge
# 11   29.616387    3.701709   0.235290    BayesianRidge
# 12   38.198327    2.076515   0.110098    BayesianRidge
# 13   22.485318    0.256885   0.046637    BayesianRidge
# 14   32.247108    7.218966   0.950371    BayesianRidge
# 15   82.232977   13.652143   0.815671    BayesianRidge
# 16   25.935896    1.294202   0.131734    BayesianRidge
# 17   25.470759    0.845417   0.099837    BayesianRidge
# 18   42.402376    8.192629   1.174640    BayesianRidge
# 19   20.092193    0.780237   0.071136    BayesianRidge
# 20   80.937707   80.766491   0.853719      GPRegressor
# 21  137.136156  134.493114   2.302542      GPRegressor
# 22  111.206655  111.501463   2.507909      GPRegressor
# 23   84.386807   82.594675   1.047034      GPRegressor
# 24   70.405679   70.596902   1.394361      GPRegressor
# 25  132.817573  133.079523   1.415115      GPRegressor
# 26   96.097005   97.642617   4.387298      GPRegressor
# 27   87.629851   87.470172   1.715181      GPRegressor
# 28   89.530231   87.612665   2.976656      GPRegressor
# 29  107.418465  105.271753   6.541856      GPRegressor
# 30   26.705911    1.644310   0.066538     SVMRegressor
# 31   45.967297    6.799831   0.186341     SVMRegressor
# 32   25.220567    0.276609   0.022494     SVMRegressor
# 33   26.872495    5.043139   1.539422     SVMRegressor
# 34   21.099518    0.819203   0.093758     SVMRegressor
# 35   47.687294    1.544691   0.042108     SVMRegressor
# 36   33.746340   -0.220695   0.040145     SVMRegressor
# 37   37.387589    7.763344   1.745028     SVMRegressor
# 38   21.198875    0.624654   0.069305     SVMRegressor
# 39   35.903837    2.879074   0.383422     SVMRegressor
# 40   44.340880    9.402507   0.139999     KNNRegressor
# 41  114.860837   21.124175   0.129784     KNNRegressor
# 42  111.843498   22.808351   0.146407     KNNRegressor
# 43   96.631649   16.377874   0.117679     KNNRegressor
# 44   46.061430    7.927718   0.151498     KNNRegressor
# 45   89.285299   18.515699   0.155520     KNNRegressor
# 46   84.316916   14.912766   0.179969     KNNRegressor
# 47   94.858784   17.894105   0.136684     KNNRegressor
# 48   69.013475   13.540466   0.165322     KNNRegressor
# 49   95.001952   16.344990   0.237064     KNNRegressor
# 50   63.660319   26.405943  10.754038     MLPRegressor
# 51   64.810022   12.465805   6.167099     MLPRegressor
# 52  100.468873   46.104578  19.880178     MLPRegressor
# 53   62.033597   32.897268  15.196325     MLPRegressor
# 54   33.998731    9.980798   9.641597     MLPRegressor
# 55   98.335605   11.328958   8.404393     MLPRegressor
# 56   38.771181   12.967840  13.859406     MLPRegressor
# 57   52.061354   29.299943  18.036147     MLPRegressor
# 58   28.340505    4.477530  11.290211     MLPRegressor
# 59   35.361733    4.394016  10.944626     MLPRegressor

# %%
# Calculate the average of each column for each algorithm
average_results = results_df.groupby('algorithm').mean()
average_results
# Out:
#                  mean_perf   distance      speed
# algorithm
# BayesianRidge    34.142216   4.348499   0.435829
# GPRegressor      99.756613  99.102938   2.514167
# KNNRegressor     84.621472  15.884865   0.155992
# LinearRegressor  36.279888   4.477498   0.088263
# MLPRegressor     57.784192  19.032268  12.417402
# SVMRegressor     32.178972   2.717416   0.418856
